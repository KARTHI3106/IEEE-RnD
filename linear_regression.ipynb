# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTHI3106/IEEE-RnD/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **IEEE RnD - Section 2**

# %% [markdown]
# #Importing The Required Libraries
#
#
#
#
#
# *   matplotlib==3.7.1
#
# *  pandas==2.0.1
# *  numpy==1.23.5

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Feeding The Dataset And The Main Program
#
# **Before using gradient descent**

# %%
data = pd.read_csv('/content/sample_data/Salary_Data.csv')
print(data.columns)
x = data['YearsExperience'].values #years_of_experience

y = data['Salary'].values

xs = x.shape[0]
xy = y.shape[0]

mx = np.mean(x)

my = np.mean(y)


m, c = np.polyfit(x, y, 1)  # Degree 1 for linear regression
y_predicted = m*x+c


s1 = np.sum((y-y_predicted)**2)
s2 = np.sum((y-my)**2)
r2 = 1-(s1/s2)
print(f'the r_squared val is :{r2}')


plt.scatter(x,y_predicted, color='red')
plt.plot(x,y_predicted,color = 'grey',linewidth='2')

plt.plot(mx,my,'g*',ms=10)



plt.plot([x,x],[y,reg_line],ls='dashed')

print(mx,my,'the mean of experince and salary')

plt.scatter(x,y,marker='o')





plt.show()
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')
# the r_squared val is :0.9569566641435086
# 5.3133333333333335 76003.0

# %% [markdown]
# **Plot of X and Y**
#
#
# ![plot.png](data:image/png;base64,...)
#
#
#
# **Scatter points of X and Y .**
#
# ![image.png](data:image/png;base64,...)
#
# The plot with the regression line (in landscape for clear view)
# ![image.png](data:image/png;base64,...)
#
#
# *   The grey line is the  regression line where the red points are the predicted value
#
#
# *   The dashed line connects the regression line to input value(x,y) which is the error between the given value and the predicted value
#
#
# *   The r_squared values is also found to find how good the model has performed
# *

# %% [markdown]
# **After using gradient descent**

# %%
data = pd.read_csv('/content/sample_data/Salary_Data.csv')
print(data.columns)
x = data['YearsExperience'].values #years_of_experience

y = data['Salary'].values

xs = x.shape[0]
xy = y.shape[0]

mx = np.mean(x)

my = np.mean(y)
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')
